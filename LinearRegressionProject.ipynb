# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sal=pd.read_csv("/content/Salary_Data.csv")
sal
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
sal.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
sal.tail(7)
# Out:
#     YearsExperience  Salary
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
sal.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sal.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sal.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
sal.shape
# Out:
# (30, 2)

# %%
sal.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
print("BASIC INFO")
print(sal.info())
# Out:
# BASIC INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes
# None

# %%
x=sal["YearsExperience"]
y=sal["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mse)
print(r2)
# Out:
# 49830096.85590839
# 0.9024461774180497

# %%
plt.scatter(x,y, color="red")
plt.plot(x_test,y_pred, color="green")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()

# %%
plt.bar(x,y, color="blue")
plt.plot(x_test,y_pred, color="green")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.lineplot(x="YearsExperience",y="Salary",data=sal,palette="pastel")
plt.title("LINE PLOT",fontsize=8)
plt.show()
# Out:
# <ipython-input-31-f92d970b7461>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x="YearsExperience",y="Salary",data=sal,palette="pastel")

# %%
plt.figure(figsize=(3,2))
sns.boxplot(x="YearsExperience",y="Salary",data=sal,palette="pastel")
plt.title("LINE PLOT",fontsize=8)
plt.show()
# Out:
# <ipython-input-32-a7c34f8bbf0c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="YearsExperience",y="Salary",data=sal,palette="pastel")
